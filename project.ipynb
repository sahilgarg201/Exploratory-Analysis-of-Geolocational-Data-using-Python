# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import json
from pandas import json_normalize
from pandas.io.json import json_normalize

# %%
food_path= 'C:/Users/hp/OneDrive/Desktop/Crio project/food_coded.csv'

# %%
food_data= pd.read_csv(food_path)

# %%
food_data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %%
food_data=food_data.dropna(axis=0)
food_data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
#
#    coffee                                  comfort_food  \
# 1       2                   chocolate, chips, ice cream
# 2       2               frozen yogurt, pizza, fast food
# 4       2                  Ice cream, chocolate, chips
# 6       2  Chocolate, ice cream, french fries, pretzels
# 7       1              Ice cream, cheeseburgers, chips.
#
#                                 comfort_food_reasons  \
# 1                               Stress, bored, anger
# 2                                    stress, sadness
# 4                         Stress, boredom, cravings
# 6                                    stress, boredom
# 7  I eat comfort food when im stressed out from s...
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 4                         1.0  ...   1.0     1.0          4             940.0
# 6                         1.0  ...   1.0     1.0          5             940.0
# 7                         1.0  ...   1.0     2.0          1             725.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 4              500     Softball           4         2              760
# 6              690       soccer           4         1             1315
# 7              500         none           4         2             1315
#
#                      weight
# 1                       155
# 2  I'm not answering this.
# 4                       190
# 6                       180
# 7                       137
#
# [5 rows x 61 columns]

# %%
important_features=['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']
food_data_final=food_data[important_features]
food_data_final.head()
# Out:
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
# 6   2.0           2         3.0            5       1.0          4     4.0
# 7   3.0           2         2.0            2       2.0          5     5.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 4            1.0             4     1.0            4
# 6            2.0             2     1.0            4
# 7            1.0             5     2.0            4

# %%
fig, ax = plt.subplots(figsize=(20,50 ))
sns.boxplot(data=food_data_final,ax=ax)
# Out:
# <AxesSubplot:>

# %%
x = food_data_final.iloc[:, [6]].values

# %%
kmeans5 = KMeans(n_clusters=5)
y_kmeans5 = kmeans5.fit_predict(x)
print(y_kmeans5)

kmeans5.cluster_centers_
# Out:
# [2 1 1 2 0 2 3 0 0 0 0 1 0 1 1 2 1 0 1 2 1 2 1 0 1 0 2 1 1 1 0 0 1 1 4 0 1
#  3 1 0 3 3 0 1 2 0 1 1 1 1 1 2]
# array([[5.],
#        [6.],
#        [4.],
#        [3.],
#        [2.]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1,11 ), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:3: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters = i).fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:4: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   kmeans.fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:3: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters = i).fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:4: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:3: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters = i).fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:4: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:3: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters = i).fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:4: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   kmeans.fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:3: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters = i).fit(x)
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/991890646.py:4: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   kmeans.fit(x)

# %%
kmeans2 = KMeans(n_clusters=3)
y_kmeans2 = kmeans2.fit_predict(x)
print(y_kmeans2)

kmeans2.cluster_centers_
# Out:
# [1 0 0 1 2 1 1 2 2 2 2 0 2 0 0 1 0 2 0 1 0 1 0 2 0 2 1 0 0 0 2 2 0 0 1 2 0
#  1 0 2 1 1 2 0 1 2 0 0 0 0 0 1]
# array([[6.        ],
#        [3.57142857],
#        [5.        ]])

# %%
plt.scatter(x[:,0],x[:,0],c=y_kmeans2,cmap='rainbow')

# %%
import requests
url = "https://api.foursquare.com/v3/places/search?&ll=13.0306,77.5649&radius=2000&limit=50&query=restaurant*cafe"

headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}

res = requests.request("GET", url, headers=headers)
result = json.loads(res.content)
print(res.text)
#data = requests.get(url).json()
# Out:
# {"message":"Endpoint '/v3/venues/search' not found."}

# %%
from time import sleep
restaurant = []
params = {}
restaurant.extend(result['results'])
sleep(2)
while "next_page_token" in result:
    params['pagetoken'] = result['next_page_token'],
    res = requests.get(url, params1 = params)
    result= json.loads(res.content)
    restaurant.extend(result['results'])
    sleep(2)

# %%
shop_name= []
shop_location = []
shop_lat = []
shop_lon = []
shop_distance=[]
shop_category=[]
shop_long=[]
shop_postcode=[]

for i in range (len (restaurant)):
    shop = restaurant[i]
    try:
        shop_name.append(shop ['name'])
    except:
        shop_name.append('none')
    try:
        shop_location.append(shop ['location']['address'])
    except:
        shop_location.append('none')
    try:
        shop_postcode.append(shop ['location']['postcode'])
    except:
        shop_postcode.append('none')
    try:
        shop_lat.append(shop['geocodes']['main']['latitude'])
    except:
        shop_lat.append('none')
    try:
        shop_long.append(shop['geocodes']['main']['longitude'])
    except:
        shop_long.append('none')
    try:
        shop_distance.append(shop['distance'])
    except:
        shop_distance.append('none')
    try:
        shop_category.append(shop['categories']['name'])
    except:
        shop_category.append('none')

# %%
df_dict = {'shop_name':shop_name,'shop_address': shop_location, 'shop_lat':shop_lat ,'shop_lon' :shop_lon}
df_dict1={'shop_name':shop_name,'shop_address': shop_location,'shop_distance':shop_distance,'shop_lat':shop_lat,'shop_long':shop_long,'shop_postcode':shop_postcode}
restaurant_df = pd.DataFrame(df_dict1)
restaurant_df.head(10)
# Out:
#                  shop_name                                       shop_address  \
# 0          Cafe Coffee Day                                      Hmt Main Road
# 1  Ice N Spice by truffles                       Near Ramaiah Medical College
# 2                    Hunan  Samruddi Building, Building No. 10, 1st Main, ...
# 3                Chung Wah                                           Bel Road
# 4                      KFC       No 117, Shop No 1, Aegs Layout, New Bel Road
# 5          Cafe Coffee Day                       RMV II Stage 80 ft Road #379
# 6                Mezzaluna  Movenpick Hotel .And Spa, 115, Gokula Extensio...
# 7             Sagar Samrat                                   186 New Bel Road
# 8                   Freska                                    2/4 80 Ft. Road
# 9        Thatte Idly Point                                               none
#
#    shop_distance   shop_lat  shop_long shop_postcode
# 0            607  13.031717  77.559406        941735
# 1            932  13.028079  77.573116        941735
# 2            610  13.034178  77.569179        560054
# 3            798  13.027713  77.571655
# 4            570  13.032088  77.569940        560054
# 5           1309  13.027355  77.576525        560094
# 6           1706  13.042339  77.554738        560013
# 7            545  13.033605  77.568882        560094
# 8           1298  13.027441  77.576444        941735
# 9            413  13.028248  77.561935        560054

# %%
import requests
url = "https://api.foursquare.com/v3/places/search?&ll=13.0306,77.5649&radius=2000&limit=50&query=gym"

headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}
res= requests.request("GET", url, headers=headers)
results = json.loads(res.content)
print(res.text)


#data1 = requests.get(url).json()
# Out:
# {"results":[{"fsq_id":"59e981b9ee71207a0250d8cf","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":1088,"geocodes":{"main":{"latitude":13.040344,"longitude":77.56384}},"location":{"country":"IN","cross_street":"","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Elite Gym And Fitness Center","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ef87f27e300930670f0ae46","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":594,"geocodes":{"main":{"latitude":13.030998193142407,"longitude":77.57037425227004}},"location":{"address":"No 3, Sapthagiri Janardhan Sun City","address_extended":"Near Nandini Hotel, Seenappa Layout, Devasandra, New Bel Road","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","neighborhood":["RMV Stage 2"],"postcode":"560094","region":"Karnātaka"},"name":"Crunch Fitness Regime","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c82424de602b1f7403f9a7a","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":2269,"geocodes":{"main":{"latitude":13.011771985702998,"longitude":77.55678839350443}},"location":{"address":"Rajaji","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Galaxy Club - Brigade Gateway","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5088ff6de4b0a533df75e791","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":1654,"geocodes":{"main":{"latitude":13.041670013562564,"longitude":77.55467905887805}},"location":{"country":"IN","cross_street":"","postcode":""},"name":"Gym @ Movenpick Hotel","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"50377d44e4b0cc82fcadcea7","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":1828,"geocodes":{"main":{"latitude":13.042300459662254,"longitude":77.57677684379189}},"location":{"address":"1st Main Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["RMV Stage 2"],"postcode":"560094","region":"Karnataka"},"name":"Naks Gym","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"7b649c8013734f36cdb41e51","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":840,"geocodes":{"main":{"latitude":13.037434,"longitude":77.561568}},"location":{"address":"4th Cross, 1st Main Road, Nethaji","country":"IN","locality":"Bangalore","neighborhood":["Mathikere"],"postcode":"560054","region":"Karnataka"},"name":"Bbmp Multi Gym","related_places":{}},{"fsq_id":"4d2674456e27a143839b0524","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":571,"geocodes":{"main":{"latitude":13.031729103326628,"longitude":77.57005356927004}},"location":{"country":"IN","cross_street":"","postcode":""},"name":"Snap Fitness","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4eec8d35775b3c580c6591e1","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/gym_","suffix":".png"}}],"chains":[],"distance":579,"geocodes":{"main":{"latitude":13.03370189669456,"longitude":77.56060132969147}},"location":{"country":"IN","cross_street":"","postcode":""},"name":"Sun Fitness Centre","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4fcca211e4b0ff719b5ca0d2","categories":[{"id":18021,"name":"Gym and Studio","icon":{"prefix":"https:/ ...

# %%
gym = []
params1 = {}
gym.extend(results['results'])
sleep(2)
while "next_page_token" in results:
    params1['pagetoken'] = results['next_page_token'],
    res1 = requests.get(url, params1 = params1)
    results = json.loads(res1.content)
    gym.extend(results['results'])
    sleep(2)

# %%
shop_name_gym= []
shop_location_gym = []
shop_lat_gym= []
shop_lon_gym= []
shop_distance_gym=[]
shop_category_gym=[]
shop_long_gym=[]
shop_postcode_gym=[]

for i in range (len (gym)):
    shop_gym = gym[i]
    try:
        shop_name_gym.append(shop_gym ['name'])
    except:
        shop_name_gym.append('none')
    try:
        shop_location_gym.append(shop_gym['location']['address'])
    except:
        shop_location_gym.append('none')
    try:
        shop_postcode_gym.append(shop_gym ['location']['postcode'])
    except:
        shop_postcode_gym.append('none')
    try:
        shop_lat_gym.append(shop_gym['geocodes']['main']['latitude'])
    except:
        shop_lat_gym.append('none')
    try:
        shop_long_gym.append(shop_gym['geocodes']['main']['longitude'])
    except:
        shop_long_gym.append('none')
    try:
        shop_distance_gym.append(shop_gym['distance'])
    except:
        shop_distance_gym.append('none')
    try:
        shop_category_gym.append(shop_gym['categories']['name'])
    except:
        shop_category_gym.append('none')

# %%
df_dict2={'shop_name':shop_name_gym,'shop_address': shop_location_gym,'shop_distance':shop_distance_gym,'shop_lat':shop_lat_gym,'shop_long':shop_long_gym,'shop_postcode':shop_postcode_gym}
gym_df = pd.DataFrame(df_dict2)
gym_df.head(10)
# Out:
#                        shop_name                         shop_address  \
# 0   Elite Gym And Fitness Center                                 none
# 1          Crunch Fitness Regime  No 3, Sapthagiri Janardhan Sun City
# 2  Galaxy Club - Brigade Gateway                               Rajaji
# 3          Gym @ Movenpick Hotel                                 none
# 4                       Naks Gym                        1st Main Road
# 5                 Bbmp Multi Gym    4th Cross, 1st Main Road, Nethaji
# 6                   Snap Fitness                                 none
# 7             Sun Fitness Centre                                 none
# 8                Reforma Fitness                      Ms Ramaiah Road
# 9                 Target Fitness                         New Bel Road
#
#    shop_distance   shop_lat  shop_long shop_postcode
# 0           1088  13.040344  77.563840        560094
# 1            594  13.030998  77.570374        560094
# 2           2269  13.011772  77.556788
# 3           1654  13.041670  77.554679
# 4           1828  13.042300  77.576777        560094
# 5            840  13.037434  77.561568        560054
# 6            571  13.031729  77.570054
# 7            579  13.033702  77.560601
# 8            592  13.030182  77.559448        560022
# 9            647  13.030484  77.570883

# %%
import requests
url = "https://api.foursquare.com/v3/places/search?&ll=13.0306,77.5649&radius=2000&limit=50&query=grocery+stores"

headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}

respo = requests.request("GET", url, headers=headers)
results1 = json.loads(respo.content)
print(respo.text)
#data2 = requests.get(url).json()
# Out:
# {"results":[{"fsq_id":"4f6577c7e4b0c65cc53f3fbd","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":1230,"geocodes":{"main":{"latitude":13.034659,"longitude":77.575471}},"location":{"address":"Sanjaynagar","country":"IN","cross_street":"Rajgopal Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Smart","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c96e53df7cfa1cd5344ca15","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":1299,"geocodes":{"main":{"latitude":13.03780339614365,"longitude":77.5743556022644}},"location":{"address":"At Rms Bus Stop, Sanjay","country":"IN","locality":"Bangalore","region":"Karnātaka"},"name":"Food World","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5d596f45d2d99a0008235543","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":1715,"geocodes":{"main":{"latitude":13.044539,"longitude":77.571703}},"location":{"address":"Tower-6, Pebble","country":"IN","cross_street":"1st Main Road, RMV II Stage","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"The Bay Store","related_places":{"parent":{"fsq_id":"4ddcfe0bc65bfd579e1ed0b3","name":"Pebble Bay"}},"timezone":"Asia/Kolkata"},{"fsq_id":"d24493b8c61a45b5c24af79a","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":460,"geocodes":{"main":{"latitude":13.027794,"longitude":77.561775}},"location":{"country":"IN","locality":"Bangalore","neighborhood":["Jalahalli"],"postcode":"560054","region":"Karnataka"},"name":"Pallavi Enterprises","related_places":{}},{"fsq_id":"906c628f9e364decf041c9e2","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":562,"geocodes":{"main":{"latitude":13.031411,"longitude":77.570026}},"location":{"country":"IN","region":"Karnataka"},"name":"City Super Market","related_places":{}},{"fsq_id":"b2c606732046459016f3369f","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":859,"geocodes":{"main":{"latitude":13.034195,"longitude":77.557867}},"location":{"address":"3rd Main Road","country":"IN","locality":"Bangalore","neighborhood":["Mathikere Extension"],"postcode":"560054","region":"Karnataka"},"name":"Mathikere Market","related_places":{}},{"fsq_id":"2065c00a3a7342cab951ca06","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":927,"geocodes":{"main":{"latitude":13.022887,"longitude":77.561632}},"location":{"country":"IN","neighborhood":["Jalahalli"],"postcode":"560022","region":"Karnataka"},"name":"Ram Mohan Traders","related_places":{}},{"fsq_id":"d1eef81ec0f3400028249d9a","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":1240,"geocodes":{"main":{"latitude":13.033988,"longitude":77.553983}},"location":{"address":"B Narayanaswamappa Road","country":"IN","locality":"Bangalore","postcode":"560054","region":"Karnataka"},"name":"More","related_places":{}},{"fsq_id":"db6161f55aa444c1b9d4d391","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".pn ...

# %%
import json
import time
grocery = []
params2 = {}
grocery.extend(results1['results'])
time.sleep(2)
while "next_page_token" in results1:
    params2['pagetoken'] = results1['next_page_token'],
    res2 = requests.get(url, params2 = params2)
    results1 = json.loads(res2.content)
    grocery.extend(results1['results'])
    time.sleep(2)

# %%
shop_name= []
shop_location = []
shop_lat = []
shop_lon = []
shop_distance=[]
shop_category=[]
shop_long=[]
shop_postcode=[]

for i in range (len (grocery)):
    shop = grocery[i]
    try:
        shop_name.append(shop ['name'])
    except:
        shop_name.append('none')
    try:
        shop_location.append(shop ['location']['address'])
    except:
        shop_location.append('none')
    try:
        shop_postcode.append(shop ['location']['postcode'])
    except:
        shop_postcode.append('none')
    try:
        shop_lat.append(shop['geocodes']['main']['latitude'])
    except:
        shop_lat.append('none')
    try:
        shop_long.append(shop['geocodes']['main']['longitude'])
    except:
        shop_long.append('none')
    try:
        shop_distance.append(shop['distance'])
    except:
        shop_distance.append('none')
    try:
        shop_category.append(shop['categories']['name'])
    except:
        shop_category.append('none')

# %%
df_dict = {'shop_name':shop_name,'shop_address': shop_location, 'shop_lat':shop_lat ,'shop_lon' :shop_lon}
df_dict3={'shop_name':shop_name,'shop_address': shop_location,'shop_distance':shop_distance,'shop_lat':shop_lat,'shop_long':shop_long,'shop_postcode':shop_postcode}
grocery_df = pd.DataFrame(df_dict3)
grocery_df.head(10)
# Out:
#               shop_name                                       shop_address  \
# 0                 Smart                                        Sanjaynagar
# 1            Food World                            At Rms Bus Stop, Sanjay
# 2         The Bay Store                                    Tower-6, Pebble
# 3   Pallavi Enterprises                                               none
# 4     City Super Market                                               none
# 5      Mathikere Market                                      3rd Main Road
# 6     Ram Mohan Traders                                               none
# 7                  More                            B Narayanaswamappa Road
# 8  Shopwel Super Market  No.68, 3rd Crs, Ngef Lyt, Nt Shastry Memorial ...
# 9              Sanjay s                                               none
#
#    shop_distance   shop_lat  shop_long shop_postcode
# 0           1230  13.034659  77.575471        560094
# 1           1299  13.037803  77.574356          none
# 2           1715  13.044539  77.571703        560094
# 3            460  13.027794  77.561775        560054
# 4            562  13.031411  77.570026          none
# 5            859  13.034195  77.557867        560054
# 6            927  13.022887  77.561632        560022
# 7           1240  13.033988  77.553983        560054
# 8           1529  13.036820  77.577498        560094
# 9           1576  13.032714  77.579296        336165

# %%
import requests
url = "https://api.foursquare.com/v3/places/search?&ll=13.0306,77.5649&radius=2000&limit=50"

headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}

res3 = requests.request("GET", url, headers=headers)
results3 = json.loads(res3.content)
print(res3.text)
#data3 = requests.get(url).json()
d=pd.json_normalize(results3)
#d.to_csv('api-data/apartment.csv')
# Out:
# {"results":[{"fsq_id":"4f8fcd83e4b0d6c8aa46afed","categories":[{"id":13214,"name":"Kerala Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":309,"geocodes":{"main":{"latitude":13.02995294340458,"longitude":77.56211592726794}},"location":{"country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Thalassery Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c027ab8cbd876b0254ef143","categories":[{"id":10000,"name":"Arts and Entertainment","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_","suffix":".png"}},{"id":13003,"name":"Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}}],"chains":[],"distance":957,"geocodes":{"main":{"latitude":13.038235183981934,"longitude":77.56899161656254}},"location":{"address":"4/1, Rmv 2nd Stage","country":"IN","cross_street":"Tank Bund Rd.","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"RMV Club","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f9a3f11e4b0193a1e94a597","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":1263,"geocodes":{"main":{"latitude":13.034403498840227,"longitude":77.57589458845183}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Chat Street","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f01a591be7bbcd4f5353e50","categories":[{"id":16032,"name":"Park","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"distance":1228,"geocodes":{"main":{"latitude":13.039978893249698,"longitude":77.57090908547546}},"location":{"address":"Dollars Colony","country":"IN","cross_street":"3rd Main","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"BBMP Park","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5fecb92ea6930e53ea44bbb8","categories":[{"id":13035,"name":"Coffee Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}}],"chains":[],"distance":1249,"geocodes":{"main":{"latitude":13.027578,"longitude":77.576013}},"location":{"address":"No.81, 2nd Cross, 80Ft Road","country":"IN","cross_street":"RMV II Stage, Sanjaynagar","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Starbucks","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d7cd7c4da568cfa30846dff","categories":[{"id":17033,"name":"Department Store","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_","suffix":".png"}}],"chains":[],"distance":739,"geocodes":{"main":{"latitude":13.037194021073432,"longitude":77.56582048673407}},"location":{"country":"IN","cross_street":"New BEL Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Maha Bazaar","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ced12544cd4236a8cdfa563","categories":[{"id":16032,"name":"Park","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"distance":1391,"geocodes":{"main":{"latitude":13.038751321222442,"longitude":77.5551380739094}},"location":{"address":"Mathikere","country":"IN","cross_street":"Jalahalli,","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Jp park","related_places":{"children":[{"fsq_id":"4fd9eccee4b03cbadd5269db","name":"Musical Fountain, JP Park"},{"fsq_id":"4fd9eb99e4b0e967fd1c8bf1","name":"JP Park Lake"},{"fsq_id":"5395b1ba498e65d34f36d247","name":"Jogging Track, JP Park"}]},"timezone":"Asia/Kolkata"},{"fsq_id":"4bf0ff0524f020a129a4684f","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":290,"geocodes":{"main":{"latitude":13.03065243971108 ...

# %%
import json
import time
all = []
params3 = {}
all.extend(results3['results'])
time.sleep(2)
while "next_page_token" in results3:
    params3['pagetoken'] = results3['next_page_token'],
    res3 = requests.get(url, params3 = params3)
    results3 = json.loads(res3.content)
    all.extend(results3['results'])
    time.sleep(2)

# %%
shop_name= []
shop_location = []
shop_lat = []
shop_lon = []
shop_distance=[]
shop_category=[]
shop_long=[]
shop_postcode=[]

for i in range (len (all)):
    shop = all[i]
    try:
        shop_name.append(shop ['name'])
    except:
        shop_name.append('none')
    try:
        shop_location.append(shop ['location']['address'])
    except:
        shop_location.append('none')
    try:
        shop_postcode.append(shop ['location']['postcode'])
    except:
        shop_postcode.append('none')
    try:
        shop_lat.append(shop['geocodes']['main']['latitude'])
    except:
        shop_lat.append('none')
    try:
        shop_long.append(shop['geocodes']['main']['longitude'])
    except:
        shop_long.append('none')
    try:
        shop_distance.append(shop['distance'])
    except:
        shop_distance.append('none')
    try:
        shop_category.append(shop['categories']['name'])
    except:
        shop_category.append('none')

# %%
df_dict = {'shop_name':shop_name,'shop_address': shop_location, 'shop_lat':shop_lat ,'shop_lon' :shop_lon}
df_dict4={'shop_name':shop_name,'shop_address': shop_location,'shop_distance':shop_distance,'shop_lat':shop_lat,'shop_long':shop_long,'shop_postcode':shop_postcode}
all_df = pd.DataFrame(df_dict4)
#df_evaluate=all_df[['shop_lat','shop_lon']]
all_df.head(10)
# Out:
#                shop_name                 shop_address  shop_distance  \
# 0  Thalassery Restaurant                         none            309
# 1    Drops Total Spirits                 New Bel Road            631
# 2               RMV Club           4/1, Rmv 2nd Stage            957
# 3            Chat Street                         none           1263
# 4              BBMP Park               Dollars Colony           1228
# 5              Starbucks  No.81, 2nd Cross, 80Ft Road           1249
# 6            Maha Bazaar                         none            739
# 7                Jp park                    Mathikere           1391
# 8      Biriyani Paradise      Triveni Road, Mathikere            290
# 9             The BEL ST                         none            609
#
#     shop_lat  shop_long shop_postcode
# 0  13.029953  77.562116
# 1  13.034719  77.568919        560054
# 2  13.038235  77.568992        560094
# 3  13.034403  77.575895        941735
# 4  13.039979  77.570909
# 5  13.027578  77.576013        560094
# 6  13.037194  77.565820        560094
# 7  13.038751  77.555138        560054
# 8  13.030652  77.562216        560057
# 9  13.030093  77.570509

# %%
# RestList=[]
# FruitList=[]
# count=0
# count1=0
# for lat, lng in zip(shop_lat, shop_lon):
#     count=count+1
    

#     all = []
#     params4 = {}
#     all.extend(results4['results'])
#     time.sleep(2)
#     while "next_page_token" in results3:
#         params4['pagetoken'] = results4['next_page_token'],
#         res4 = requests.get(url, params4 = params4)
#         results4 = json.loads(res4.content)
#         all.extend(results4['results'])
#         time.sleep(2)
        
#     RestList.append(count)

# print(shop_lat[0])
# Out:
# 13.02995294340458

# %%
venues = results3['results']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/3357318313.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                      fsq_id  \
# 0  4f8fcd83e4b0d6c8aa46afed
# 1  4c027ab8cbd876b0254ef143
# 2  4f9a3f11e4b0193a1e94a597
# 3  4f01a591be7bbcd4f5353e50
# 4  5fecb92ea6930e53ea44bbb8
#
#                                           categories chains  distance  \
# 0  [{'id': 13214, 'name': 'Kerala Restaurant', 'i...     []       309
# 1  [{'id': 10000, 'name': 'Arts and Entertainment...     []       957
# 2  [{'id': 13145, 'name': 'Fast Food Restaurant',...     []      1263
# 3  [{'id': 16032, 'name': 'Park', 'icon': {'prefi...     []      1228
# 4  [{'id': 13035, 'name': 'Coffee Shop', 'icon': ...     []      1249
#
#                     name      timezone  geocodes.main.latitude  \
# 0  Thalassery Restaurant  Asia/Kolkata               13.029953
# 1               RMV Club  Asia/Kolkata               13.038235
# 2            Chat Street  Asia/Kolkata               13.034403
# 3              BBMP Park  Asia/Kolkata               13.039979
# 4              Starbucks  Asia/Kolkata               13.027578
#
#    geocodes.main.longitude location.country      location.cross_street  \
# 0                77.562116               IN
# 1                77.568992               IN              Tank Bund Rd.
# 2                77.575895               IN
# 3                77.570909               IN                   3rd Main
# 4                77.576013               IN  RMV II Stage, Sanjaynagar
#
#   location.locality location.postcode location.region  \
# 0         Bangalore                         Karnātaka
# 1         Bangalore            560094       Karnātaka
# 2               NaN            941735             NaN
# 3         Bangalore                         Karnātaka
# 4         Bangalore            560094       Karnātaka
#
#               location.address related_places.children location.neighborhood  \
# 0                          NaN                     NaN                   NaN
# 1           4/1, Rmv 2nd Stage                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3               Dollars Colony                     NaN                   NaN
# 4  No.81, 2nd Cross, 80Ft Road                     NaN                   NaN
#
#   location.address_extended related_places.parent.fsq_id  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   related_places.parent.name
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
import folium
#define coordinates of the college
map_bang=folium.Map(location=[13.133521,77.567135],zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

latitudes = list(all_df.shop_lat)
longitudes = list( all_df.shop_long)
labels = list(all_df.shop_name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(map_bang)    
    
# add incidents to map
map_bang.add_child(locations)

# add incidents to map
map_bang.add_child(locations)

map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_68df5da945f24690895c8d3c547f5a6a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_68df5da945f24690895c8d3c547f5a6a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_68df5da945f24690895c8d3c547f5a6a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_68df5da945f24690895c8d3c547f5a6a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B13.133521%2C%2077.567135%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
df_evaluate=all_df[['shop_lat','shop_long']]

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
RestList=[]
latitudes = list(all_df.shop_lat)
longitudes = list( all_df.shop_long)
for lat, lng in zip(latitudes, longitudes):    
    radius = 2000 #Set the radius to 5 kilometres for convenience
    latitude=lat#Query for the apartment location in question
    longitude=lng
    # url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    # search_query = 'Restaurant' #Search for any food related locations
    # results = requests.get(url).json()
    # assign relevant part of JSON to venues
    url = "https://api.foursquare.com/v3/places/search?&ll={},{}&radius=2000&limit=50&query=restaurant".format(lat,lng)

    headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}

    respo = requests.request("GET", url, headers=headers)
    resultso = json.loads(respo.content)
    print(respo.text)

    venues = resultso['results']
    # # tranform venues into a dataframe
    dataframe2 = json_normalize(venues)
    filtered_columns = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('geocodes.main.')] + ['fsq_id']
    dataframe_filtered2 = dataframe2.loc[:, filtered_columns]
    # # filter the category for each row
    dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)
    # # clean column names by keeping only last term
    dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]
    RestList.append(dataframe_filtered2['categories'].count())
# Out:
# {"results":[{"fsq_id":"4f8fcd83e4b0d6c8aa46afed","categories":[{"id":13214,"name":"Kerala Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":0,"geocodes":{"main":{"latitude":13.02995294340458,"longitude":77.56211592726794}},"location":{"country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Thalassery Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bf0ff0524f020a129a4684f","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":78,"geocodes":{"main":{"latitude":13.030652439711085,"longitude":77.5622161145674}},"location":{"address":"Triveni Road, Mathikere","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["T Dasarahalli"],"postcode":"560057","region":"Karnātaka"},"name":"Biriyani Paradise","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"51664734e4b0fa985027d659","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":13,"geocodes":{"main":{"latitude":13.029895803258485,"longitude":77.56223017980612}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Hotel Thalaserry","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"512658ede4b0df3344ac24c1","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":30,"geocodes":{"main":{"latitude":13.029764955882323,"longitude":77.56191112853422}},"location":{"address":"24 4th Cross, Msrc, Mathikere, Yeshwanthpur","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Yeshwanthpur"],"postcode":"941735","region":"Karnataka"},"name":"Tasty Hot","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ddd1e2cd4c082f960d5c2fc","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":217,"geocodes":{"main":{"latitude":13.030533465479458,"longitude":77.56019532061102}},"location":{"address":"Ms Ramaiah Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Yeshwanthpur"],"postcode":"560022","region":"Karnātaka"},"name":"New Agarwal Bhawan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cdbfdd622bd721e3c94f847","categories":[{"id":13334,"name":"Sandwich Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"distance":73,"geocodes":{"main":{"latitude":13.02933154,"longitude":77.56188497}},"location":{"address":"Near Msrit","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Hot burger, the campus Special","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"512b7906e4b0e22f0d2b1b51","categories":[{"id":13051,"name":"Fish and Chips Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fishandchips_","suffix":".png"}}],"chains":[],"distance":125,"geocodes":{"main":{"latitude":13.028855241379752,"longitude":77.56183276492656}},"location":{"address":"1065/33, 4th Main, Gokula","country":"IN","cross_street":"","postcode":"560054"},"name":"Fish Corner","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5ba47a703092be002c96cdbe","categories":[{"id":13028,"name":"Breakfast Spot","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/breakfast_","suffix":".png"}}],"chains":[],"distance":190,"geocodes":{"main":{"latitude":13.028248,"longitude":77.561935}},"location":{"country":"IN","cross_street":"","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Thatte Idly Point","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ed39cc25c5c9528fd014aff","categories":[{"id":13 ...
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/3610179087.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe2 = json_normalize(venues)
# {"results":[{"fsq_id":"4bd5644f5631c9b625fba330","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":66,"geocodes":{"main":{"latitude":13.034177957710094,"longitude":77.56917870939733}},"location":{"address":"Samruddi Building, Building No. 10, 1st Main, New Del Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Hunan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4beec08a35dc0f470f34405b","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[{"id":"ab4beec0-d68a-012e-5619-003048cad9da","name":"KFC"}],"distance":312,"geocodes":{"main":{"latitude":13.032088315306128,"longitude":77.56994022488833}},"location":{"address":"No 117, Shop No 1, Aegs Layout, New Bel Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["MSR Nagar"],"postcode":"560054","region":"Karnātaka"},"name":"KFC","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4b5d696bf964a5203e5c29e3","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":123,"geocodes":{"main":{"latitude":13.033605457426669,"longitude":77.56888200761529}},"location":{"address":"186 New Bel Road","address_extended":"Opposite Ramaiah Hospital, Raj Mahal Vilas Extension","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Raj Mahal Vilas Extension"],"postcode":"560094","region":"Karnātaka"},"name":"Sagar Samrat","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"504f06c1e4b06a753d0db6f6","categories":[{"id":13200,"name":"Andhra Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":67,"geocodes":{"main":{"latitude":13.034933630830272,"longitude":77.56833675995728}},"location":{"address":"No 4 New Bel Road","address_extended":"Opposite Johny Walker, Rmv Extension 2nd Stage","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["RMV Extension"],"postcode":"941735","region":"Karnataka"},"name":"Cauvery Hyderabadi Biriyani","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":542,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"559ebd93498eba17e2ff062a","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":376,"geocodes":{"main":{"latitude":13.032,"longitude":77.571}},"location":{"address":"Ground Floor, Old No 14/529, New No 14, New Bellary Road, Chickkamaranahalli","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd813790b779c74ac4c06a0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":" ...
# {"results":[{"fsq_id":"4d52ba92d7eaa1437dee810f","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":509,"geocodes":{"main":{"latitude":13.039037941581752,"longitude":77.56435436666399}},"location":{"address":"Chandrappa Complex","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Kanti Sweets","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5006bce3e4b0d41b583a8478","categories":[{"id":13001,"name":"Bagel Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bagels_","suffix":".png"}}],"chains":[],"distance":55,"geocodes":{"main":{"latitude":13.037733306376476,"longitude":77.56897482541483}},"location":{"address":"Tank Bund Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Bagels and Bakes","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd813790b779c74ac4c06a0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":370,"geocodes":{"main":{"latitude":13.037154305456458,"longitude":77.56574938632659}},"location":{"address":"Ground Floor No 278/280 Property Id No 62-114-23 10th Cross Ward No 62 Wilson Garden","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560027","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd5644f5631c9b625fba330","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":451,"geocodes":{"main":{"latitude":13.034177957710094,"longitude":77.56917870939733}},"location":{"address":"Samruddi Building, Building No. 10, 1st Main, New Del Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Hunan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cc00e6419ceb1f7d3cb26cd","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}},{"id":13377,"name":"Vegan and Vegetarian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/vegetarian_","suffix":".png"}}],"chains":[],"distance":354,"geocodes":{"main":{"latitude":13.036967574802603,"longitude":77.56598537226097}},"location":{"address":"34/A, New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Shanthi Sagar Fast Food","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4fd85b31e4b000122d6fbbca","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":349,"geocodes":{"main":{"latitude":13.035856,"longitude":77.566878}},"location":{"address":"Devasandra","country":"IN","cross_street":"New Bel Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Prashanth Hotel","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f9a3f11e4b0193a1e94a597","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":860,"geocodes":{"main":{"latitude":13.034403498840227,"longitude":77.57589458845183}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Chat Street","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"504f06c1e4b06a75 ...
# {"results":[{"fsq_id":"4f9a3f11e4b0193a1e94a597","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":0,"geocodes":{"main":{"latitude":13.034403498840227,"longitude":77.57589458845183}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Chat Street","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"56cc9c38cd10c894087c9a1b","categories":[{"id":13026,"name":"BBQ Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bbqalt_","suffix":".png"}}],"chains":[],"distance":47,"geocodes":{"main":{"latitude":13.034785110457644,"longitude":77.57609404873651}},"location":{"country":"IN","cross_street":"","postcode":"931735"},"name":"Salaam Sigri","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bf79364508c0f471ac53d31","categories":[{"id":13003,"name":"Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}}],"chains":[],"distance":323,"geocodes":{"main":{"latitude":13.031631806553102,"longitude":77.57681170630248}},"location":{"address":"38/40/41, D Rajgopal Road, Sanjay Nagar Main Road","address_extended":"Opposite Rmv Hospital, Geddala Halli, Sanjay","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["RMV Stage 2"],"postcode":"560094","region":"Karnātaka"},"name":"Ujwal Family Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":764,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":754,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":765,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"559ebd93498eba17e2ff062a","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":593,"geocodes":{"main":{"latitude":13.032,"longitude":77.571}},"location":{"address":"Ground Floor, Old No 14/529, New No 14, New Bellary Road, Chickkamaranahalli","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd5644f5631c9b625fba330","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":727,"geocodes":{"main":{"latitude":13.03417795771 ...
# {"results":[{"fsq_id":"4d52ba92d7eaa1437dee810f","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":717,"geocodes":{"main":{"latitude":13.039037941581752,"longitude":77.56435436666399}},"location":{"address":"Chandrappa Complex","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Kanti Sweets","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd5644f5631c9b625fba330","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":671,"geocodes":{"main":{"latitude":13.034177957710094,"longitude":77.56917870939733}},"location":{"address":"Samruddi Building, Building No. 10, 1st Main, New Del Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Hunan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd813790b779c74ac4c06a0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":640,"geocodes":{"main":{"latitude":13.037154305456458,"longitude":77.56574938632659}},"location":{"address":"Ground Floor No 278/280 Property Id No 62-114-23 10th Cross Ward No 62 Wilson Garden","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560027","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5006bce3e4b0d41b583a8478","categories":[{"id":13001,"name":"Bagel Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bagels_","suffix":".png"}}],"chains":[],"distance":325,"geocodes":{"main":{"latitude":13.037733306376476,"longitude":77.56897482541483}},"location":{"address":"Tank Bund Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Bagels and Bakes","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f9a3f11e4b0193a1e94a597","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":821,"geocodes":{"main":{"latitude":13.034403498840227,"longitude":77.57589458845183}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Chat Street","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cc00e6419ceb1f7d3cb26cd","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}},{"id":13377,"name":"Vegan and Vegetarian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/vegetarian_","suffix":".png"}}],"chains":[],"distance":629,"geocodes":{"main":{"latitude":13.036967574802603,"longitude":77.56598537226097}},"location":{"address":"34/A, New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Shanthi Sagar Fast Food","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":1099,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"559ebd93498eba17e2ff062a","categ ...
# {"results":[{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":318,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfe25a64cf820a1fe7fedf4","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":122,"geocodes":{"main":{"latitude":13.027429308669463,"longitude":77.57489204406738}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Have More","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5749a4dc498ea9eeff3810f0","categories":[{"id":13034,"name":"Café","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"chains":[],"distance":60,"geocodes":{"main":{"latitude":13.027355,"longitude":77.576525}},"location":{"address":"RMV II Stage 80 ft Road #379","country":"IN","cross_street":"Devasandra Main Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Cafe Coffee Day","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":322,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bed56889868a59340355d46","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":49,"geocodes":{"main":{"latitude":13.027440899303501,"longitude":77.5764443792013}},"location":{"address":"2/4 80 Ft. Road","address_extended":"Opposite Ms Ramaiah Hospital","country":"IN","cross_street":"RMV Extension","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Freska","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c0b4e06340720a12a038893","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":379,"geocodes":{"main":{"latitude":13.027681017685401,"longitude":77.57951929618572}},"location":{"address":"Ashwath","country":"IN","cross_street":"","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Paratha Plaza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cf8a22dd1dd721ed72ba49b","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":472,"geocodes":{"main":{"latitude":13.027713334748974,"longitude":77.57165540730685}},"location":{"address":"Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Chung Wah","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d16fe7a81cea35dbdb2e3ec","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":129,"geocodes":{"main":{"latitude":13.027192285308647,"longitude":77.57714424770094}},"location":{"address":"3 80 Feet Road","address_extended":"Opposite Ramaiah Hospital","country":"IN","cross_street":"","locality":"Bangalo ...
# {"results":[{"fsq_id":"4bd813790b779c74ac4c06a0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":8,"geocodes":{"main":{"latitude":13.037154305456458,"longitude":77.56574938632659}},"location":{"address":"Ground Floor No 278/280 Property Id No 62-114-23 10th Cross Ward No 62 Wilson Garden","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560027","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d52ba92d7eaa1437dee810f","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":259,"geocodes":{"main":{"latitude":13.039037941581752,"longitude":77.56435436666399}},"location":{"address":"Chandrappa Complex","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Kanti Sweets","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cc00e6419ceb1f7d3cb26cd","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}},{"id":13377,"name":"Vegan and Vegetarian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/vegetarian_","suffix":".png"}}],"chains":[],"distance":30,"geocodes":{"main":{"latitude":13.036967574802603,"longitude":77.56598537226097}},"location":{"address":"34/A, New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Shanthi Sagar Fast Food","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d0f0d0a7177b1f76d7f4922","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":42,"geocodes":{"main":{"latitude":13.037489726401649,"longitude":77.56556617088802}},"location":{"address":"21 New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Akshaya Deluxe","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bd5644f5631c9b625fba330","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":494,"geocodes":{"main":{"latitude":13.034177957710094,"longitude":77.56917870939733}},"location":{"address":"Samruddi Building, Building No. 10, 1st Main, New Del Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Hunan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4fd85b31e4b000122d6fbbca","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":187,"geocodes":{"main":{"latitude":13.035856,"longitude":77.566878}},"location":{"address":"Devasandra","country":"IN","cross_street":"New Bel Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Prashanth Hotel","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"51e809c1498e69847d31f9fe","categories":[{"id":13054,"name":"Food Truck","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/streetfood_","suffix":".png"}}],"chains":[],"distance":203,"geocodes":{"main":{"latitude":13.03861335695601,"longitude":77.56462583434852}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"SLK Golgappa","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5006bce3e4b0d41b583a8 ...
# {"results":[{"fsq_id":"4f734b06e4b0601c70d3a30f","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":401,"geocodes":{"main":{"latitude":13.042339214023034,"longitude":77.55473783528103}},"location":{"address":"Movenpick Hotel .And Spa, 115, Gokula Extension, Hmt Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Mathikere"],"postcode":"560013","region":"Karnātaka"},"name":"Mezzaluna","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"51616bb9498e5d9da50aea08","categories":[{"id":13034,"name":"Café","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"chains":[],"distance":140,"geocodes":{"main":{"latitude":13.039389123032215,"longitude":77.55625761497667}},"location":{"address":"Da Costa Square","country":"IN","cross_street":"Wheeler Road Extension,","locality":"Bangalore","postcode":"560084","region":"Karnātaka"},"name":"Cafe Da Costa","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cee70a8f368b1f796b880f7","categories":[{"id":13002,"name":"Bakery","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}}],"chains":[],"distance":140,"geocodes":{"main":{"latitude":13.039870055084206,"longitude":77.55573775202377}},"location":{"address":"Gokula","country":"IN","cross_street":"Gokula extension","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Basyer's Day Fresh","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f95246be4b0e90bfd076197","categories":[{"id":13002,"name":"Bakery","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}}],"chains":[],"distance":146,"geocodes":{"main":{"latitude":13.039910426286186,"longitude":77.55577529974789}},"location":{"address":"Gokul Tower","country":"IN","cross_street":"","postcode":"941735"},"name":"Dayfresh Basyir","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"544e156f498ecb0abce55923","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":146,"geocodes":{"main":{"latitude":13.039774529119873,"longitude":77.55598949729067}},"location":{"address":"86 Ground Floor, Gokul Towers, Off Msramiah Road, Gokula, New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Gokula"],"postcode":"560054","region":"Karnataka"},"name":"Flavours Inn","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4e0840fbc65b5bf27794bce9","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":176,"geocodes":{"main":{"latitude":13.039693,"longitude":77.556452}},"location":{"address":"Gokula","country":"IN","cross_street":"","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Gokul Restaurant (Kedai Korea)","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5313490d498e66f707ff0390","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":399,"geocodes":{"main":{"latitude":13.042325211045174,"longitude":77.55475182967763}},"location":{"address":"Bel Circle","country":"IN","cross_street":"","postcode":""},"name":"My Place @ Mövenpick Hotel and Spa, Bangalore","related_places":{"parent":{"fsq_id":"4dc3270952b1e8f9f79b0161","name":"Mövenpick Hotel and Spa"}},"timezone":"Asia/Kolkata"},{"fsq_id":"4d52ba92d7eaa1437dee810f","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":998,"geocodes":{"main":{"latitude":13.039037941581752,"longitude":77.56435436666399}},"location":{"address":"Chandrappa Complex","country":"IN","cross_street":"New  ...
# {"results":[{"fsq_id":"4bf0ff0524f020a129a4684f","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":0,"geocodes":{"main":{"latitude":13.030652439711085,"longitude":77.5622161145674}},"location":{"address":"Triveni Road, Mathikere","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["T Dasarahalli"],"postcode":"560057","region":"Karnātaka"},"name":"Biriyani Paradise","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f8fcd83e4b0d6c8aa46afed","categories":[{"id":13214,"name":"Kerala Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":78,"geocodes":{"main":{"latitude":13.02995294340458,"longitude":77.56211592726794}},"location":{"country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Thalassery Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ddd1e2cd4c082f960d5c2fc","categories":[{"id":13065,"name":"Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"distance":219,"geocodes":{"main":{"latitude":13.030533465479458,"longitude":77.56019532061102}},"location":{"address":"Ms Ramaiah Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Yeshwanthpur"],"postcode":"560022","region":"Karnātaka"},"name":"New Agarwal Bhawan","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"51664734e4b0fa985027d659","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":84,"geocodes":{"main":{"latitude":13.029895803258485,"longitude":77.56223017980612}},"location":{"country":"IN","cross_street":"","postcode":"941735"},"name":"Hotel Thalaserry","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"512658ede4b0df3344ac24c1","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":104,"geocodes":{"main":{"latitude":13.029764955882323,"longitude":77.56191112853422}},"location":{"address":"24 4th Cross, Msrc, Mathikere, Yeshwanthpur","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Yeshwanthpur"],"postcode":"941735","region":"Karnataka"},"name":"Tasty Hot","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cdbfdd622bd721e3c94f847","categories":[{"id":13334,"name":"Sandwich Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"distance":151,"geocodes":{"main":{"latitude":13.02933154,"longitude":77.56188497}},"location":{"address":"Near Msrit","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Hot burger, the campus Special","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4ed39cc25c5c9528fd014aff","categories":[{"id":13034,"name":"Café","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"chains":[],"distance":326,"geocodes":{"main":{"latitude":13.031717399707885,"longitude":77.55940591512328}},"location":{"address":"Hmt Main Road","country":"IN","cross_street":"Mathikere","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Cafe Coffee Day","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"512b7906e4b0e22f0d2b1b51","categories":[{"id":13051,"name":"Fish and Chips Shop","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fishandchips_","suffix":".png"}}],"chains":[],"distance":203,"geocodes":{"main":{"latitude":13.028855241379752,"longitude":77.56183276492656}},"location":{"address":"1065/33, 4th Main, Gokula","country":"IN","cross_street":"","postcode":"560054"},"name":"Fish Corner","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"558d0985498 ...
# {"results":[{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":0,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":360,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d1987a2bb64224bd993cf65","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":91,"geocodes":{"main":{"latitude":13.029383216855765,"longitude":77.57093272638218}},"location":{"address":"#19","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560094","region":"Karnātaka"},"name":"Relish Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cf8a22dd1dd721ed72ba49b","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":292,"geocodes":{"main":{"latitude":13.027713334748974,"longitude":77.57165540730685}},"location":{"address":"Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Chung Wah","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":357,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c8c48893ad9ef3b229addc0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":90,"geocodes":{"main":{"latitude":13.029331692777662,"longitude":77.57081508636475}},"location":{"address":"Shashi Arcade, Ground Floor, 215, New Bel Road","country":"IN","cross_street":"215, Mathikere (New BEL Road)","locality":"Bangalore","postcode":"560049","region":"Karnātaka"},"name":"McDonald's","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"559ebd93498eba17e2ff062a","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":218,"geocodes":{"main":{"latitude":13.032,"longitude":77.571}},"location":{"address":"Ground Floor, Old No 14/529, New No 14, New Bellary Road, Chickkamaranahalli","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"52ecce46498ee3079aae5e85","categories":[{"id":13003,"name":"Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","s ...
# {"results":[{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":101,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"559ebd93498eba17e2ff062a","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4afc60-d68a-012e-5619-003048cad9da","name":"Domino's Pizza"}],"distance":130,"geocodes":{"main":{"latitude":13.032,"longitude":77.571}},"location":{"address":"Ground Floor, Old No 14/529, New No 14, New Bellary Road, Chickkamaranahalli","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560054","region":"Karnātaka"},"name":"Domino's Pizza","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4beec08a35dc0f470f34405b","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[{"id":"ab4beec0-d68a-012e-5619-003048cad9da","name":"KFC"}],"distance":129,"geocodes":{"main":{"latitude":13.032088315306128,"longitude":77.56994022488833}},"location":{"address":"No 117, Shop No 1, Aegs Layout, New Bel Road","address_extended":"1st Floor","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["MSR Nagar"],"postcode":"560054","region":"Karnātaka"},"name":"KFC","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":439,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d1987a2bb64224bd993cf65","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":189,"geocodes":{"main":{"latitude":13.029383216855765,"longitude":77.57093272638218}},"location":{"address":"#19","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560094","region":"Karnātaka"},"name":"Relish Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5009625be4b0adf259c2ab6b","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":42,"geocodes":{"main":{"latitude":13.031287412429538,"longitude":77.5701223775955}},"location":{"address":"16 Next To Levi's Showroom","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","postcode":"560054","region":"Karnātaka"},"name":"Eggstacy","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"52ecce46498ee3079aae5e85","categories":[{"id":13003,"name":"Bar","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}}],"chains":[],"distance":69,"geocodes":{"main":{"latitude":13.030378,"longitude":77.570465}},"location":{"address":"New Bel Road","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["RMV Stage 2"],"postcode":"560054","region":"Karnātaka"},"name":"Sanoria Wine Lounge","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","c ...
# ...
# {"results":[{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":125,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":270,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cf8a22dd1dd721ed72ba49b","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":170,"geocodes":{"main":{"latitude":13.027713334748974,"longitude":77.57165540730685}},"location":{"address":"Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Chung Wah","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4d1987a2bb64224bd993cf65","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":45,"geocodes":{"main":{"latitude":13.029383216855765,"longitude":77.57093272638218}},"location":{"address":"#19","country":"IN","cross_street":"New BEL Road","locality":"Bangalore","neighborhood":["New BEL Road"],"postcode":"560094","region":"Karnātaka"},"name":"Relish Restaurant","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":267,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0555a130f801541e6ed079","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13039,"name":"Deli","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[{"id":"ab4bee40-d68a-012e-5619-003048cad9da","name":"Subway"}],"distance":165,"geocodes":{"main":{"latitude":13.02776960768549,"longitude":77.57166583590954}},"location":{"address":"Corporation Ward No. 100, Anjaneya Temple Street Corner, New Bel Road, Devasandra","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Devasandra"],"postcode":"941735","region":"Karnataka"},"name":"Subway","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c8c48893ad9ef3b229addc0","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":37,"geocodes":{"main":{"latitude":13.029331692777662,"longitude":77.57081508636475}},"location":{"address":"Shashi Arcade, Ground Floor, 215, New Bel Road","country":"IN","cross_street":"215, Mathikere (New BEL Road)","locality":"Bangalore","postcode":"560049","region":"Karnātaka"},"name":"McDonald's","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c03ed3ef423a5935bdcd016","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categorie ...
# {"results":[{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":41,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":43,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cf8a22dd1dd721ed72ba49b","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":198,"geocodes":{"main":{"latitude":13.027713334748974,"longitude":77.57165540730685}},"location":{"address":"Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Chung Wah","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4e2be94d7d8b7deda6d5bd7e","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":22,"geocodes":{"main":{"latitude":13.028198336230275,"longitude":77.57324529376803}},"location":{"address":"Plot No 82, 80 Feet Road, R.M.V 2nd Stage, Dollars Colony, Rmv Extension","address_extended":"Opposite Ramaiah Hospital, Next To Baskin Robbins","country":"IN","cross_street":"R.M.V 2nd Stage","locality":"Bangalore","neighborhood":["RMV Extension"],"postcode":"560094","region":"Karnātaka"},"name":"Jashn","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0555a130f801541e6ed079","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13039,"name":"Deli","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[{"id":"ab4bee40-d68a-012e-5619-003048cad9da","name":"Subway"}],"distance":195,"geocodes":{"main":{"latitude":13.02776960768549,"longitude":77.57166583590954}},"location":{"address":"Corporation Ward No. 100, Anjaneya Temple Street Corner, New Bel Road, Devasandra","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Devasandra"],"postcode":"941735","region":"Karnataka"},"name":"Subway","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"552011bb498eb4cd79a2d51a","categories":[{"id":13236,"name":"Italian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"distance":363,"geocodes":{"main":{"latitude":13.030093260288147,"longitude":77.57050852320651}},"location":{"country":"IN","cross_street":"","neighborhood":["New BEL Road"],"postcode":"","region":"Karnataka"},"name":"The BEL ST","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfe25a64cf820a1fe7fedf4","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":195,"geocodes":{"main":{"latitude":13.027429308669463,"longitude":77.57489204406738}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Have More","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c03ed3ef423a5935bdcd016","categories":[{"id":13145,"name":" ...
# {"results":[{"fsq_id":"4f0b2674e4b0ca3a5efdaeaf","categories":[{"id":13031,"name":"Burger Joint","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}}],"chains":[],"distance":23,"geocodes":{"main":{"latitude":13.028079028167316,"longitude":77.57311592249596}},"location":{"address":"Near Ramaiah Medical College","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"941735","region":"Karnātaka"},"name":"Ice N Spice by truffles","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfd10ba4cf820a16bd9ebf4","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"distance":27,"geocodes":{"main":{"latitude":13.028078629411786,"longitude":77.57308292276954}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Ice and Spice","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4cf8a22dd1dd721ed72ba49b","categories":[{"id":13099,"name":"Chinese Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}}],"chains":[],"distance":186,"geocodes":{"main":{"latitude":13.027713334748974,"longitude":77.57165540730685}},"location":{"address":"Bel Road","country":"IN","cross_street":"","locality":"Bangalore","postcode":"","region":"Karnātaka"},"name":"Chung Wah","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4e2be94d7d8b7deda6d5bd7e","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":17,"geocodes":{"main":{"latitude":13.028198336230275,"longitude":77.57324529376803}},"location":{"address":"Plot No 82, 80 Feet Road, R.M.V 2nd Stage, Dollars Colony, Rmv Extension","address_extended":"Opposite Ramaiah Hospital, Next To Baskin Robbins","country":"IN","cross_street":"R.M.V 2nd Stage","locality":"Bangalore","neighborhood":["RMV Extension"],"postcode":"560094","region":"Karnātaka"},"name":"Jashn","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4f0555a130f801541e6ed079","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13039,"name":"Deli","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[{"id":"ab4bee40-d68a-012e-5619-003048cad9da","name":"Subway"}],"distance":183,"geocodes":{"main":{"latitude":13.02776960768549,"longitude":77.57166583590954}},"location":{"address":"Corporation Ward No. 100, Anjaneya Temple Street Corner, New Bel Road, Devasandra","country":"IN","cross_street":"","locality":"Bangalore","neighborhood":["Devasandra"],"postcode":"941735","region":"Karnataka"},"name":"Subway","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4bfe25a64cf820a1fe7fedf4","categories":[{"id":13199,"name":"Indian Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"distance":182,"geocodes":{"main":{"latitude":13.027429308669463,"longitude":77.57489204406738}},"location":{"address":"New Bel Road","country":"IN","cross_street":"80 Feet Road","locality":"Bangalore","postcode":"560094","region":"Karnātaka"},"name":"Have More","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"4c03ed3ef423a5935bdcd016","categories":[{"id":13145,"name":"Fast Food Restaurant","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}},{"id":13064,"name":"Pizzeria","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[{"id":"ab4a6b90-d68a-012e-5619-003048cad9da","name":"Pizza Hut"}],"distance":193,"geocodes":{"main":{"latitude":13.027686007513845,"longitude":77.57159267519111}},"location":{"address":"3 New Bel Road","address_extended":"Near-St ...

# %%
df_evaluate['Restaurants']=RestList

# %%
FruitList=[]
latitudes = list(all_df.shop_lat)
longitudes = list( all_df.shop_long)
for lat, lng in zip(latitudes, longitudes):    
    radius = 2000 #Set the radius to 5 kilometres for convenience
    latitude=lat#Query for the apartment location in question
    longitude=lng
    # url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    # search_query = 'Restaurant' #Search for any food related locations
    # results = requests.get(url).json()
    # assign relevant part of JSON to venues
    url = "https://api.foursquare.com/v3/places/search?&ll={},{}&radius=2000&query=fruit*grocery".format(lat,lng)

    headers = {"Authorization": "fsq3fcsIMQS31PpzBXWFje54WUC6v+nJy1HC6c1d3eCrTbQ=","Accept": "application/json"}

    res5 = requests.request("GET", url, headers=headers)
    results5 = json.loads(res5.content)


    venues = results5['results']
    # # tranform venues into a dataframe
    dataframe3 = json_normalize(venues)
    filtered_columns = ['name', 'categories'] + [col for col in dataframe3.columns if col.startswith('geocodes.main.')] + ['fsq_id']
    dataframe_filtered3 = dataframe3.loc[:, filtered_columns]
    # # filter the category for each row
    dataframe_filtered3['categories'] = dataframe_filtered3.apply(get_category_type, axis=1)
    # # clean column names by keeping only last term
    dataframe_filtered3.columns = [column.split('.')[-1] for column in dataframe_filtered3.columns]
    FruitList.append(dataframe_filtered3['categories'].count())
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_13736/3192669065.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe3 = json_normalize(venues)

# %%
df_evaluate['Fruits,Vegetables,Groceries']=FruitList

# %%
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_evaluate)
df_evaluate['Cluster']=kmeans.labels_
df_evaluate['Cluster']=df_evaluate['Cluster'].apply(str)
df_evaluate.head(10)
# Out:
#     shop_lat  shop_long  Restaurants  restaurants  \
# 0  13.029953  77.562116           50           50
# 1  13.034719  77.568919           50           50
# 2  13.038235  77.568992           50           50
# 3  13.034403  77.575895           50           50
# 4  13.039979  77.570909           50           50
# 5  13.027578  77.576013           50           50
# 6  13.037194  77.565820           50           50
# 7  13.038751  77.555138           50           50
# 8  13.030652  77.562216           50           50
# 9  13.030093  77.570509           50           50
#
#    Fruits,Vegetables,Groceries Cluster
# 0                           10       0
# 1                           10       0
# 2                           10       1
# 3                           10       0
# 4                           10       2
# 5                           10       0
# 6                           10       0
# 7                           10       0
# 8                           10       0
# 9                           10       0

# %%
#define coordinates of the college
map_bang=folium.Map(location=[13.133521,77.567135],zoom_start=12)
# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()
def color_producer(Cluster):
    if Cluster=='0':
        return 'green'
    elif Cluster=='1':
        return 'orange'
    else:
        return 'red'
latitudes = list(df_evaluate.shop_lat)
longitudes = list( df_evaluate.shop_long)
labels = list(df_evaluate.Cluster)
names=list(all_df.shop_name)
for lat, lng, labels,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(labels)
        ).add_to(map_bang)  
    
# add incidents to map
map_bang.add_child(locations)

# add incidents to map
map_bang.add_child(locations)

map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_583de851ba1e4094869c4b8a65c1cd6c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_583de851ba1e4094869c4b8a65c1cd6c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_583de851ba1e4094869c4b8a65c1cd6c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_583de851ba1e4094869c4b8a65c1cd6c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B13.133521%2C%2077.567135%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
